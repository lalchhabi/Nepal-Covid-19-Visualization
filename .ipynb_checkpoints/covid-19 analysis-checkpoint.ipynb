# %% [markdown]
# # Importing the Libraries and Datas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("country_wise_latest.csv")

# %% [markdown]
# # Analyzing the Datas

# %%
dataset.head(10)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      23546     446       3928   19172        656
# 1              Albania       1416      36       1034     346         31
# 2              Algeria      10698     751       7322    2625        109
# 3              Andorra        853      51        781      21          1
# 4               Angola        130       5         42      83         12
# 5  Antigua and Barbuda         26       3         20       3          0
# 6            Argentina      28764     785       8743   19236       1391
# 7              Armenia      15281     258       5639    9384        612
# 8            Australia       7294     102       6803     389          5
# 9              Austria      17064     675      15985     404         30
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          20            602                1.89                  16.68
# ...

# %%
dataset.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
dataset.tail(30)
# Out:
#            Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 157                 Spain     243209   27136     150376    65697        502
# 158             Sri Lanka       1880      11       1196      673          3
# 159                 Sudan       6879     433       2416     4030        149
# 160              Suriname        187       3          9      175         19
# 161                Sweden      49684    4854          0    44830       1396
# 162           Switzerland      31063    1938      28800      325         19
# 163                 Syria        164       6          0      158          0
# 164               Taiwan*        443       7        431        5          0
# 165            Tajikistan       4902      49       3158     1695         68
# 166              Tanzania        509      21        183      305          0
# 167              Thailand       3129      58       2987       84          4
# ...

# %%
dataset.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      23546     446       3928   19172        656
# 1               Albania       1416      36       1034     346         31
# 2               Algeria      10698     751       7322    2625        109
# 3               Andorra        853      51        781      21          1
# 4                Angola        130       5         42      83         12
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza        489       3        414      72          2
# 183      Western Sahara          9       1          6       2          0
# 184               Yemen        632     139         28     465         41
# 185              Zambia       1321      10       1104     207        121
# 186            Zimbabwe        343       4         51     288         11
#
# ...

# %%
sns.relplot(x = "Confirmed", y = "Deaths", data = dataset)

# %%
sns.relplot(x = 'Confirmed' , y = "Recovered", data = dataset)

# %%
sns.relplot(x = "Confirmed", y = "New cases", data = dataset)

# %%
sns.relplot(x = "Confirmed", y = "Deaths", hue = "Recovered", data = dataset)
